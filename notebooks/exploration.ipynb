# %%
import pandas as pd

df = pd.read_csv(
    "../data/raw/fact_laps_2025.csv"
)

df.head()
# Out:
#     RaceName Driver  DriverNumber             Team  LapNumber  \
# 0  Australia    VER             1  Red Bull Racing        1.0
# 1  Australia    VER             1  Red Bull Racing        2.0
# 2  Australia    VER             1  Red Bull Racing        3.0
# 3  Australia    VER             1  Red Bull Racing        4.0
# 4  Australia    VER             1  Red Bull Racing        5.0
#
#                   LapTime             Sector1Time             Sector2Time  \
# 0  0 days 00:01:59.392000                     NaN  0 days 00:00:20.705000
# 1                     NaN  0 days 00:00:58.141000  0 days 00:00:37.976000
# 2                     NaN  0 days 00:00:56.230000  0 days 00:00:33.683000
# 3                     NaN  0 days 00:00:54.351000  0 days 00:00:32.712000
# 4  0 days 00:02:23.609000  0 days 00:00:53.513000  0 days 00:00:32.627000
#
#               Sector3Time      Compound  TyreLife  Stint  Position  SpeedST  \
# ...

# %%
df.columns
# Out:
# Index(['RaceName', 'Driver', 'DriverNumber', 'Team', 'LapNumber', 'LapTime',
#        'Sector1Time', 'Sector2Time', 'Sector3Time', 'Compound', 'TyreLife',
#        'Stint', 'Position', 'SpeedST', 'IsPersonalBest'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26990 entries, 0 to 26989
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   RaceName        26990 non-null  object
#  1   Driver          26990 non-null  object
#  2   DriverNumber    26990 non-null  int64
#  3   Team            26990 non-null  object
#  4   LapNumber       26990 non-null  float64
#  5   LapTime         26727 non-null  object
#  6   Sector1Time     26477 non-null  object
#  7   Sector2Time     26941 non-null  object
#  8   Sector3Time     26938 non-null  object
#  9   Compound        26579 non-null  object
#  10  TyreLife        26556 non-null  float64
#  11  Stint           26636 non-null  float64
#  12  Position        26961 non-null  float64
#  13  SpeedST         26955 non-null  float64
#  14  IsPersonalBest  26973 non-null  object
# dtypes: float64(5), int64(1), object(9)
# memory usage: 3.1+ MB

# %%
df.describe()
# Out:
#        DriverNumber     LapNumber      TyreLife         Stint      Position  \
# count  26990.000000  26990.000000  26556.000000  26636.000000  26961.000000
# mean      29.552056     30.892701     14.952779      1.951344      9.790364
# std       24.881770     18.436862     10.250636      0.917816      5.419923
# min        1.000000      1.000000      1.000000      1.000000      1.000000
# 25%       10.000000     15.000000      7.000000      1.000000      5.000000
# 50%       22.000000     30.000000     13.000000      2.000000     10.000000
# 75%       44.000000     45.000000     21.000000      2.000000     14.000000
# max       87.000000     78.000000     72.000000      7.000000     20.000000
#
#             SpeedST
# count  26955.000000
# mean     299.365424
# std       31.450504
# min       54.000000
# 25%      290.000000
# 50%      305.000000
# 75%      315.000000
# max      364.000000

# %%
import matplotlib.pyplot as plt

df["Position"].value_counts().plot()
plt.show()
